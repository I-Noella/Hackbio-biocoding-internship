# %% [markdown]
# <a href="https://colab.research.google.com/github/I-Noella/Hackbio-biocoding-internship/blob/main/Stage_zero_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_details={
    'Name': "Mustapha Esther Inioluwa",
    'Slack_username': "Inioluwa",
    'Email': "Estherqueen904@gmail.com",
    'Hobby': "Enjoying my Me-time",
    'Country': "Nigeria",
    'Discipline': "Veterinary Medicine",
    "Preferred_programming_language": "Python"
}
print(my_details)
# Out:
# {'Name': 'Mustapha Esther Inioluwa', 'Slack_username': 'Inioluwa', 'Email': 'Estherqueen904@gmail.com', 'Hobby': 'Enjoying my Me-time', 'Country': 'Nigeria', 'Discipline': 'Veterinary Medicine', 'Preferred_programming_language': 'Python'}
